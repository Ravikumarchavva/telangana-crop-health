# %%
# Standard Library Imports
from concurrent.futures import ThreadPoolExecutor, as_completed
from joblib import Parallel, delayed
from tqdm import tqdm
from datetime import datetime
from pathlib import Path
import os
import random

# Third-Party Imports
import ee
import geemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rasterio
from lightgbm import LGBMClassifier
from shapely.affinity import scale, translate
from skimage import exposure
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder

from shapely import wkt
import geopandas as gpd

import warnings
warnings.filterwarnings('ignore')

import logging
# Set up a logger to capture Rasterio warnings
logging.getLogger("rasterio._env").setLevel(logging.ERROR)

from my_configs.configs import Config
from my_utils.utils import Utils

rooth_path = Config.ROOT_PATH
train_path = Config.TRAIN_CSV
test_path = Config.TEST_CSV

# Authenticate with Google Earth Engine
# This opens a browser prompt for authentication, if not previously authenticated
ee.Authenticate()

# Initialize Earth Engine with a specific project
# Replace "project" with your project ID as needed
ee.Initialize(project=Config.PROJECT)

# %%
# Load the datasets
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# Convert pandas DataFrames to GeoDataFrames with CRS set to 'epsg:4326'
train = gpd.GeoDataFrame(train, crs='epsg:4326', geometry=train['geometry'].apply(wkt.loads))
test = gpd.GeoDataFrame(test, crs='epsg:4326', geometry=test['geometry'].apply(wkt.loads))

# Concatenate train and test datasets into a single DataFrame for consistent processing
# 'dataset' column distinguishes between train and test rows
data = pd.concat(
    [train.assign(dataset='train'), test.assign(dataset='test')]
).reset_index(drop=True)

download = True
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
if download:
    error_indices = []  # Initialize list to collect indices of error rows
    # Execute image downloads for each row in parallel to improve performance
    with ThreadPoolExecutor(max_workers=4) as executor:  # Adjust the number of workers as needed
        futures = [executor.submit(Utils.process_row, index, row) for index, row in data.iterrows()]
        for future in tqdm(as_completed(futures), total=len(futures), desc="Downloading Images", unit="image"): 
            index, image_file = future.result() # Get the result from the future object                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ``
            if image_file:
                data.at[index, 'tif_path'] = image_file  # Store the downloaded file path
            else:
                error_indices.append(index)  # Collect indices of rows with errors
    
    # Save error rows to a separate CSV file
    if error_indices:
        error_rows = data.loc[error_indices]
        error_rows.to_csv('error_rows.csv', index=False)
        logging.info(f"Saved {len(error_indices)} error rows to error_rows.csv")
    else:
        logging.info("All images downloaded successfully without errors.")
else:
    # Load existing data with image paths if downloads are not required
    os.system('cp -r ./downloads .')
    data_path = "./data.csv"

    data = pd.read_csv(data_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# c:\Users\chavv\anaconda\envs\telangana\lib\site-packages\ee\deprecation.py:207: DeprecationWarning:
#
# Attention required for COPERNICUS/S2! You are using a deprecated asset.
# To ensure continued functionality, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2
#
#   warnings.warn(warning, category=DeprecationWarning)
# Downloading Images:   0%|          | 3/10606 [00:03<2:45:37,  1.07image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 5/10606 [00:04<2:28:14,  1.19image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 7/10606 [00:07<4:14:46,  1.44s/image]
# Downloading data from https://earthengine.googleapis.com/v1/projects/zinditelangana2k24/thumbnails/65024423128d86999044f0bc698ba60c-b0efaee48c20b158b3135998cf8b912d:getPixels
# Please wait ...
# Downloading Images:   0%|          | 8/10606 [00:08<3:40:53,  1.25s/image]
# Data downloaded to d:\github\telangana-crop-health\downloads\20240527T050651_20240527T051452_T43QHV_RGB_2023-11-20_2024-05-30.tif
# Downloading Images:   0%|          | 9/10606 [00:12<6:05:46,  2.07s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 11/10606 [00:13<3:43:17,  1.26s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 13/10606 [00:14<2:59:32,  1.02s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 14/10606 [00:16<4:01:54,  1.37s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 17/10606 [00:21<4:25:47,  1.51s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 20/10606 [00:24<3:48:11,  1.29s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 23/10606 [00:26<3:12:37,  1.09s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 26/10606 [00:28<2:24:43,  1.22image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 28/10606 [00:29<2:13:43,  1.32image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 32/10606 [00:37<5:22:57,  1.83s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 34/10606 [00:43<7:31:14,  2.56s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 37/10606 [00:44<3:43:08,  1.27s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 40/10606 [00:52<6:41:31,  2.28s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 44/10606 [00:56<4:45:09,  1.62s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 47/10606 [00:57<2:29:19,  1.18image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 51/10606 [01:05<4:53:17,  1.67s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   0%|          | 52/10606 [01:06<3:54:48,  1.33s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 56/10606 [01:14<6:33:31,  2.24s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 58/10606 [01:19<7:14:31,  2.47s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 59/10606 [01:20<5:30:04,  1.88s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 60/10606 [01:20<4:00:10,  1.37s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 62/10606 [01:22<3:50:45,  1.31s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 65/10606 [01:23<2:30:36,  1.17image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 68/10606 [01:26<2:57:06,  1.01s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 71/10606 [01:28<2:27:21,  1.19image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 72/10606 [01:28<1:49:35,  1.60image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 75/10606 [01:30<1:57:13,  1.50image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 81/10606 [01:45<6:14:10,  2.13s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 84/10606 [01:47<3:43:26,  1.27s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 86/10606 [01:48<2:44:06,  1.07image/s]ERROR:root:Failed to process entry for District Siddipet after attempt.
# Downloading Images:   1%|          | 88/10606 [01:49<2:26:33,  1.20image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 91/10606 [01:51<2:07:21,  1.38image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 94/10606 [01:52<1:54:35,  1.53image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 98/10606 [01:55<2:14:51,  1.30image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 103/10606 [02:04<4:24:16,  1.51s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 107/10606 [02:12<5:54:10,  2.02s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 108/10606 [02:12<4:33:12,  1.56s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 111/10606 [02:16<4:10:00,  1.43s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 112/10606 [02:16<3:02:56,  1.05s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 114/10606 [02:18<2:58:47,  1.02s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 115/10606 [02:18<2:23:17,  1.22image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 119/10606 [02:20<1:43:02,  1.70image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 122/10606 [02:22<1:54:16,  1.53image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 123/10606 [02:22<1:27:57,  1.99image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 125/10606 [02:23<1:37:50,  1.79image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 127/10606 [02:24<1:14:52,  2.33image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 129/10606 [02:25<1:41:45,  1.72image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|          | 132/10606 [02:27<1:29:03,  1.96image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 135/10606 [02:30<2:32:04,  1.15image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 138/10606 [02:31<2:00:49,  1.44image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 140/10606 [02:33<2:07:48,  1.36image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 141/10606 [02:33<1:51:00,  1.57image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 147/10606 [02:46<5:40:45,  1.95s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 149/10606 [02:47<3:27:54,  1.19s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 151/10606 [02:48<2:50:59,  1.02image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 153/10606 [02:49<2:43:11,  1.07image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 154/10606 [02:50<2:04:45,  1.40image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:   1%|▏         | 157/10606 [02:51<2:03:18,  1.41image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 161/10606 [02:54<2:25:49,  1.19image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 163/10606 [02:57<3:14:16,  1.12s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 166/10606 [03:03<5:38:14,  1.94s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 168/10606 [03:04<3:43:06,  1.28s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 169/10606 [03:05<3:10:57,  1.10s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 171/10606 [03:06<3:05:31,  1.07s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 174/10606 [03:07<1:51:33,  1.56image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 175/10606 [03:08<1:42:51,  1.69image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 180/10606 [03:12<1:55:41,  1.50image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 182/10606 [03:12<1:28:02,  1.97image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 186/10606 [03:21<5:39:14,  1.95s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 187/10606 [03:22<4:55:39,  1.70s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 190/10606 [03:24<3:12:00,  1.11s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 191/10606 [03:24<2:43:40,  1.06image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 194/10606 [03:32<6:13:53,  2.15s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 196/10606 [03:33<3:55:40,  1.36s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 198/10606 [03:33<2:25:13,  1.19image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 202/10606 [03:41<4:55:41,  1.71s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 205/10606 [03:45<4:09:32,  1.44s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 208/10606 [03:46<2:22:29,  1.22image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 210/10606 [03:48<2:36:35,  1.11image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 214/10606 [03:55<5:34:01,  1.93s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 216/10606 [03:55<3:11:47,  1.11s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 218/10606 [04:01<5:42:59,  1.98s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 226/10606 [04:05<2:21:52,  1.22image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 229/10606 [04:07<1:55:39,  1.50image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 230/10606 [04:07<1:38:26,  1.76image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 234/10606 [04:09<1:26:10,  2.01image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 236/10606 [04:12<3:04:33,  1.07s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 239/10606 [04:18<4:21:03,  1.51s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 242/10606 [04:22<4:43:43,  1.64s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 244/10606 [04:23<3:02:17,  1.06s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 246/10606 [04:24<2:51:36,  1.01image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 247/10606 [04:24<2:12:55,  1.30image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 249/10606 [04:26<2:15:12,  1.28image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 250/10606 [04:26<1:49:08,  1.58image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 253/10606 [04:31<4:18:47,  1.50s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 258/10606 [04:37<3:32:59,  1.24s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 262/10606 [04:39<2:46:51,  1.03image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   2%|▏         | 264/10606 [04:40<1:44:15,  1.65image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 266/10606 [04:41<2:01:09,  1.42image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 269/10606 [04:43<2:16:10,  1.27image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 271/10606 [04:50<5:48:43,  2.02s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 273/10606 [04:50<3:20:05,  1.16s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 275/10606 [04:51<2:27:51,  1.16image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 278/10606 [04:52<2:09:20,  1.33image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 279/10606 [04:53<1:42:08,  1.69image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 280/10606 [04:53<1:23:19,  2.07image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 282/10606 [04:54<1:42:30,  1.68image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 286/10606 [04:56<1:32:19,  1.86image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 287/10606 [04:57<1:32:48,  1.85image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 290/10606 [04:58<1:29:03,  1.93image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 292/10606 [04:59<1:22:28,  2.08image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 294/10606 [05:00<1:19:41,  2.16image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 298/10606 [05:02<1:41:11,  1.70image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 301/10606 [05:04<1:53:53,  1.51image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 304/10606 [05:08<2:50:52,  1.00image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 306/10606 [05:13<5:07:04,  1.79s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 310/10606 [05:14<2:56:41,  1.03s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 311/10606 [05:14<2:23:15,  1.20image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 314/10606 [05:16<2:19:22,  1.23image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 317/10606 [05:17<1:34:23,  1.82image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 321/10606 [05:25<4:32:14,  1.59s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:   3%|▎         | 322/10606 [05:26<3:44:21,  1.31s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 323/10606 [05:27<3:10:16,  1.11s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 326/10606 [05:29<2:32:20,  1.12image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 327/10606 [05:29<2:08:10,  1.34image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 329/10606 [05:31<2:16:55,  1.25image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 334/10606 [05:34<1:45:46,  1.62image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 335/10606 [05:34<1:22:18,  2.08image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 337/10606 [05:35<2:01:03,  1.41image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 338/10606 [05:36<1:36:37,  1.77image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 340/10606 [05:37<1:37:16,  1.76image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 343/10606 [05:39<1:54:53,  1.49image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 346/10606 [05:41<2:02:57,  1.39image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 352/10606 [05:46<2:19:17,  1.23image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 354/10606 [05:49<3:21:51,  1.18s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 358/10606 [05:52<2:45:23,  1.03image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 361/10606 [05:53<2:06:51,  1.35image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 362/10606 [05:53<1:51:57,  1.52image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 366/10606 [05:55<1:34:05,  1.81image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 368/10606 [05:57<1:49:43,  1.56image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   3%|▎         | 371/10606 [05:58<1:33:29,  1.82image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 373/10606 [05:59<1:40:06,  1.70image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 377/10606 [06:07<4:50:39,  1.70s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 379/10606 [06:07<3:13:53,  1.14s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 381/10606 [06:13<5:41:28,  2.00s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 385/10606 [06:20<5:05:46,  1.79s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 389/10606 [06:23<3:46:28,  1.33s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 391/10606 [06:28<5:39:30,  1.99s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 394/10606 [06:29<3:07:11,  1.10s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 395/10606 [06:30<2:38:18,  1.07image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▎         | 397/10606 [06:37<5:40:04,  2.00s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 399/10606 [06:37<3:45:10,  1.32s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 401/10606 [06:38<3:09:52,  1.12s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 403/10606 [06:40<2:44:51,  1.03image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 408/10606 [06:51<6:23:41,  2.26s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 409/10606 [06:51<4:48:59,  1.70s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 411/10606 [06:52<3:16:30,  1.16s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 412/10606 [06:53<2:45:25,  1.03image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 417/10606 [06:56<2:16:29,  1.24image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 418/10606 [06:56<1:49:30,  1.55image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 420/10606 [06:58<2:08:20,  1.32image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 421/10606 [06:58<1:39:47,  1.70image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 423/10606 [06:59<1:46:45,  1.59image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 424/10606 [07:00<1:38:29,  1.72image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 426/10606 [07:01<1:36:13,  1.76image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 428/10606 [07:02<2:05:17,  1.35image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 431/10606 [07:09<5:29:54,  1.95s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 433/10606 [07:10<3:38:57,  1.29s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 434/10606 [07:11<2:55:42,  1.04s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 436/10606 [07:12<2:46:55,  1.02image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 438/10606 [07:13<1:50:01,  1.54image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 441/10606 [07:15<2:07:16,  1.33image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 445/10606 [07:22<4:08:50,  1.47s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 446/10606 [07:22<3:17:49,  1.17s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 449/10606 [07:24<2:23:42,  1.18image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 454/10606 [07:27<1:49:57,  1.54image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 455/10606 [07:27<1:40:56,  1.68image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 460/10606 [07:40<5:53:37,  2.09s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 461/10606 [07:40<4:37:43,  1.64s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 464/10606 [07:42<3:28:39,  1.23s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 468/10606 [07:44<2:19:41,  1.21image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 471/10606 [07:46<2:06:40,  1.33image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 473/10606 [07:46<1:23:45,  2.02image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 475/10606 [07:48<2:05:50,  1.34image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   4%|▍         | 477/10606 [07:50<2:05:08,  1.35image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 479/10606 [07:50<1:29:42,  1.88image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 481/10606 [07:52<1:39:37,  1.69image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 484/10606 [07:54<1:57:29,  1.44image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 485/10606 [07:54<1:43:27,  1.63image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 488/10606 [07:57<2:30:39,  1.12image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 491/10606 [07:58<1:52:27,  1.50image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 493/10606 [08:00<2:36:38,  1.08image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 495/10606 [08:01<1:41:25,  1.66image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 497/10606 [08:02<1:51:03,  1.52image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 500/10606 [08:05<2:06:35,  1.33image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 505/10606 [08:10<3:33:06,  1.27s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 506/10606 [08:10<2:37:44,  1.07image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 508/10606 [08:12<2:17:31,  1.22image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 510/10606 [08:13<2:19:50,  1.20image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 517/10606 [08:16<1:21:18,  2.07image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 519/10606 [08:18<2:16:00,  1.24image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 522/10606 [08:19<1:37:18,  1.73image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 523/10606 [08:19<1:18:58,  2.13image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 526/10606 [08:22<2:01:17,  1.39image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 527/10606 [08:22<1:33:50,  1.79image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▍         | 529/10606 [08:29<6:40:55,  2.39s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 531/10606 [08:31<4:21:46,  1.56s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 534/10606 [08:32<3:08:16,  1.12s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 537/10606 [08:39<4:41:03,  1.67s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 541/10606 [08:47<4:27:40,  1.60s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 549/10606 [08:57<5:29:08,  1.96s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 554/10606 [09:05<5:00:26,  1.79s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 559/10606 [09:08<2:48:14,  1.00s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 561/10606 [09:08<1:51:02,  1.51image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 563/10606 [09:11<2:42:58,  1.03image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 564/10606 [09:11<2:06:34,  1.32image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 566/10606 [09:22<7:48:16,  2.80s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 568/10606 [09:26<6:31:23,  2.34s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 571/10606 [09:27<3:44:10,  1.34s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 573/10606 [09:28<3:05:21,  1.11s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 576/10606 [09:30<2:10:57,  1.28image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 578/10606 [09:34<3:54:41,  1.40s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 580/10606 [09:37<4:13:13,  1.52s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   5%|▌         | 581/10606 [09:38<3:40:07,  1.32s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 584/10606 [09:44<5:16:41,  1.90s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 585/10606 [09:45<3:59:31,  1.43s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 588/10606 [09:47<3:28:26,  1.25s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 589/10606 [09:48<2:47:22,  1.00s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 592/10606 [09:49<2:11:33,  1.27image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 595/10606 [09:52<2:26:57,  1.14image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 596/10606 [09:52<2:01:34,  1.37image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 599/10606 [09:58<4:30:51,  1.62s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 600/10606 [09:59<3:57:19,  1.42s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 606/10606 [10:07<3:38:41,  1.31s/image]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 610/10606 [10:10<2:15:44,  1.23image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:   6%|▌         | 616/10606 [10:19<3:24:50,  1.23s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 619/10606 [10:22<3:16:14,  1.18s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 623/10606 [10:24<2:08:31,  1.29image/s]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 625/10606 [10:25<1:52:13,  1.48image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 626/10606 [10:25<1:32:10,  1.80image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 628/10606 [10:27<1:57:59,  1.41image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 631/10606 [10:29<2:05:14,  1.33image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 632/10606 [10:30<1:52:06,  1.48image/s]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 635/10606 [10:38<5:38:43,  2.04s/image]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 637/10606 [10:38<3:51:34,  1.39s/image]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 640/10606 [10:40<2:35:20,  1.07image/s]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 646/10606 [10:44<2:10:32,  1.27image/s]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 648/10606 [10:44<1:42:34,  1.62image/s]ERROR:root:Failed to process entry for District Nagarkurnool after attempt.
# Downloading Images:   6%|▌         | 652/10606 [10:47<1:54:55,  1.44image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 655/10606 [10:50<2:26:08,  1.13image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 657/10606 [10:56<5:49:14,  2.11s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▌         | 662/10606 [10:59<2:50:08,  1.03s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 664/10606 [11:00<1:55:14,  1.44image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 667/10606 [11:02<2:26:03,  1.13image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 669/10606 [11:02<1:23:27,  1.98image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 672/10606 [11:04<1:31:24,  1.81image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 674/10606 [11:05<1:23:21,  1.99image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 675/10606 [11:05<1:11:53,  2.30image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 679/10606 [11:08<1:58:57,  1.39image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 681/10606 [11:08<1:16:18,  2.17image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 684/10606 [11:16<4:32:57,  1.65s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   6%|▋         | 685/10606 [11:16<3:34:23,  1.30s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 690/10606 [11:23<3:31:03,  1.28s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 691/10606 [11:23<2:47:59,  1.02s/image]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 693/10606 [11:25<2:34:30,  1.07image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 695/10606 [11:25<1:55:35,  1.43image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 696/10606 [11:26<1:44:20,  1.58image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 698/10606 [11:27<1:48:50,  1.52image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 701/10606 [11:29<1:30:03,  1.83image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 702/10606 [11:29<1:15:43,  2.18image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 704/10606 [11:31<2:02:10,  1.35image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 705/10606 [11:31<1:41:17,  1.63image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 711/10606 [11:34<1:15:42,  2.18image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 713/10606 [11:35<1:18:54,  2.09image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 715/10606 [11:35<53:22,  3.09image/s]  ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 718/10606 [11:38<1:53:17,  1.45image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 719/10606 [11:38<1:27:17,  1.89image/s]ERROR:root:Failed to process entry for District Narayanpet after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 722/10606 [11:39<1:35:17,  1.73image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 724/10606 [11:40<1:31:33,  1.80image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 727/10606 [11:43<2:13:46,  1.23image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 731/10606 [11:46<2:23:13,  1.15image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 735/10606 [11:50<2:29:34,  1.10image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 738/10606 [11:52<2:12:32,  1.24image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 740/10606 [11:53<1:48:46,  1.51image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 742/10606 [11:55<2:19:22,  1.18image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 744/10606 [11:56<2:10:51,  1.26image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 747/10606 [11:58<1:38:17,  1.67image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 748/10606 [11:58<1:23:23,  1.97image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 750/10606 [12:00<1:41:53,  1.61image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 751/10606 [12:00<1:23:14,  1.97image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 753/10606 [12:01<1:27:18,  1.88image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# Downloading Images:   7%|▋         | 756/10606 [12:03<1:47:14,  1.53image/s]ERROR:root:Failed to process entry for District Mahabubnagar after attempt.
# ...
# Downloading Images:  59%|█████▉    | 6297/10606 [1:42:49<1:10:09,  1.02image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  59%|█████▉    | 6302/10606 [1:42:52<1:04:24,  1.11image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  59%|█████▉    | 6303/10606 [1:42:53<50:49,  1.41image/s]  ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  59%|█████▉    | 6305/10606 [1:42:54<53:33,  1.34image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  59%|█████▉    | 6307/10606 [1:42:54<33:38,  2.13image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6311/10606 [1:42:58<51:26,  1.39image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  60%|█████▉    | 6312/10606 [1:42:58<39:52,  1.79image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6313/10606 [1:42:58<36:14,  1.97image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6315/10606 [1:43:00<42:26,  1.69image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  60%|█████▉    | 6316/10606 [1:43:00<37:26,  1.91image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6319/10606 [1:43:02<45:34,  1.57image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6320/10606 [1:43:02<42:57,  1.66image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6324/10606 [1:43:05<39:01,  1.83image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6327/10606 [1:43:09<1:18:41,  1.10s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6328/10606 [1:43:09<1:01:56,  1.15image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6331/10606 [1:43:14<1:29:34,  1.26s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6333/10606 [1:43:14<51:32,  1.38image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6335/10606 [1:43:16<58:56,  1.21image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6337/10606 [1:43:17<51:20,  1.39image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6338/10606 [1:43:17<41:55,  1.70image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6341/10606 [1:43:19<48:21,  1.47image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6342/10606 [1:43:19<38:37,  1.84image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6343/10606 [1:43:19<31:39,  2.24image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6345/10606 [1:43:21<54:14,  1.31image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6348/10606 [1:43:28<2:07:42,  1.80s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6352/10606 [1:43:35<2:11:27,  1.85s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6353/10606 [1:43:35<1:39:12,  1.40s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6355/10606 [1:43:36<1:18:24,  1.11s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6357/10606 [1:43:37<56:57,  1.24image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6359/10606 [1:43:39<1:13:35,  1.04s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6361/10606 [1:43:40<49:52,  1.42image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|█████▉    | 6363/10606 [1:43:41<53:01,  1.33image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6369/10606 [1:43:45<50:40,  1.39image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6373/10606 [1:43:47<47:59,  1.47image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6375/10606 [1:43:49<52:51,  1.33image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6377/10606 [1:43:50<57:05,  1.23image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6380/10606 [1:43:52<48:22,  1.46image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6382/10606 [1:43:53<44:39,  1.58image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6384/10606 [1:43:54<50:54,  1.38image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6387/10606 [1:43:57<1:04:52,  1.08image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6390/10606 [1:43:59<46:34,  1.51image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6392/10606 [1:43:59<29:04,  2.42image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6395/10606 [1:44:01<39:48,  1.76image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6398/10606 [1:44:03<43:01,  1.63image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6399/10606 [1:44:03<41:29,  1.69image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6405/10606 [1:44:12<1:09:55,  1.00image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6406/10606 [1:44:12<58:05,  1.21image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6410/10606 [1:44:20<1:59:07,  1.70s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6411/10606 [1:44:20<1:32:22,  1.32s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6413/10606 [1:44:22<1:24:27,  1.21s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  60%|██████    | 6416/10606 [1:44:31<2:58:21,  2.55s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6421/10606 [1:44:34<1:26:41,  1.24s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6426/10606 [1:44:37<56:49,  1.23image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6433/10606 [1:44:46<1:19:56,  1.15s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6434/10606 [1:44:46<1:09:26,  1.00image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6439/10606 [1:44:50<57:35,  1.21image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6441/10606 [1:44:50<38:36,  1.80image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6443/10606 [1:44:52<47:45,  1.45image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6446/10606 [1:44:54<48:40,  1.42image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6449/10606 [1:44:56<58:38,  1.18image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6452/10606 [1:44:58<45:49,  1.51image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6455/10606 [1:44:59<49:30,  1.40image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6457/10606 [1:45:00<30:49,  2.24image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6459/10606 [1:45:03<1:10:35,  1.02s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6461/10606 [1:45:07<2:00:24,  1.74s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6464/10606 [1:45:10<1:27:26,  1.27s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6465/10606 [1:45:10<1:10:09,  1.02s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6468/10606 [1:45:12<54:04,  1.28image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6471/10606 [1:45:14<50:17,  1.37image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6472/10606 [1:45:14<39:04,  1.76image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6476/10606 [1:45:17<47:37,  1.45image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6477/10606 [1:45:17<37:29,  1.84image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6480/10606 [1:45:19<44:18,  1.55image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6481/10606 [1:45:20<42:57,  1.60image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6483/10606 [1:45:23<1:17:33,  1.13s/image]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6487/10606 [1:45:25<52:34,  1.31image/s]  ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6489/10606 [1:45:27<59:20,  1.16image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6491/10606 [1:45:28<57:39,  1.19image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████    | 6493/10606 [1:45:30<55:27,  1.24image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████    | 6496/10606 [1:45:31<43:53,  1.56image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████▏   | 6498/10606 [1:45:33<54:34,  1.25image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████▏   | 6499/10606 [1:45:33<43:03,  1.59image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████▏   | 6502/10606 [1:45:35<44:40,  1.53image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6503/10606 [1:45:35<42:12,  1.62image/s]ERROR:root:Failed to process entry for District Medak after attempt.
# Downloading Images:  61%|██████▏   | 6507/10606 [1:45:39<1:04:27,  1.06image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6509/10606 [1:45:40<51:32,  1.32image/s]  ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6510/10606 [1:45:40<46:04,  1.48image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6512/10606 [1:45:42<48:02,  1.42image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6514/10606 [1:45:43<50:21,  1.35image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# ERROR:root:Failed to process entry for District Adilabad after attempt.
# Downloading Images:  61%|██████▏   | 6517/10606 [1:45:45<48:26,  1.41image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  61%|██████▏   | 6522/10606 [1:45:53<1:25:57,  1.26s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6523/10606 [1:45:54<1:06:56,  1.02image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6525/10606 [1:45:55<1:03:19,  1.07image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6528/10606 [1:45:58<58:03,  1.17image/s]  ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6529/10606 [1:45:58<45:39,  1.49image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6531/10606 [1:46:00<1:02:33,  1.09image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6534/10606 [1:46:01<39:39,  1.71image/s]  ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6535/10606 [1:46:04<1:18:57,  1.16s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6537/10606 [1:46:08<1:52:57,  1.67s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6539/10606 [1:46:09<1:19:17,  1.17s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6541/10606 [1:46:11<1:21:21,  1.20s/image]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6544/10606 [1:46:12<50:03,  1.35image/s]  ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6545/10606 [1:46:12<45:58,  1.47image/s]ERROR:root:Failed to process entry for District Nirmal after attempt.
# Downloading Images:  62%|██████▏   | 6546/10606 [1:46:13<36:12,  1.87image/s]ERROR:root:Failed to process entry for District Adilabad after attempt.

# %%
# Save error rows to a separate CSV file
if error_indices:
    error_rows = data.loc[error_indices]
    error_rows.to_csv('error_rows.csv', index=False)
    logging.info(f"Saved {len(error_indices)} error rows to error_rows.csv")
else:
    logging.info("All images downloaded successfully without errors.")

# Retry Mechanism for Error Rows
if os.path.exists('error_rows.csv') and not error_indices:
    logging.info("No error rows to retry.")
elif os.path.exists('error_rows.csv'):
    retry_data = pd.read_csv('error_rows.csv')
    retry_error_indices = []  # Initialize list for new error indices
    
    logging.info("Retrying failed image downloads from error_rows.csv...")
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        retry_futures = [executor.submit(Utils.process_row, index, row) for index, row in retry_data.iterrows()]
        for future in tqdm(as_completed(retry_futures), total=len(retry_futures), desc="Retrying Error Rows", unit="image"):
            index, image_file = future.result()
            if image_file:
                data.at[index, 'tif_path'] = image_file  # Update the downloaded file path
            else:
                retry_error_indices.append(index)  # Collect new errors
    
    # Save any new error rows back to CSV
    if retry_error_indices:
        new_error_rows = retry_data.loc[retry_error_indices]
        new_error_rows.to_csv('error_rows.csv', index=False)
        logging.info(f"Saved {len(retry_error_indices)} retry error rows to error_rows.csv")
    else:
        os.remove('error_rows.csv')  # Remove the file if all retries succeeded
        logging.info("All error rows re-downloaded successfully.")
